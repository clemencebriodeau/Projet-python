# %% [markdown]
# # Récupération des données

# %% [markdown]
# Dans ce notebook, on récupère les données et on les nettoie.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import urllib
import bs4
from bs4 import BeautifulSoup
from urllib import request

# %%
import os
path = os.getcwd()
os.chdir(path)
os.getcwd()
# Out:
# 'C:\\Users\\Clemence\\Documents\\Cours\\ENSAE\\2A_semestre_1\\Python\\Projet-python'

# %% [markdown]
# ## Nombre de médailles remportées pour les éditions des JO retenues
#
#
# On fait du webscrapping pour récupérer le nombre de médailles gagnées par chaque pays, pour les 8 éditions de JO d'été depuis 1992.
# On récupère ces tableaux de médailles sur le site : http://www.olympedia.org/editions/medals

# %%
code natalie

# %% [markdown]
# ## PIB par habitant des pays
#
#
# Données téléchargées sur le lien suivant : https://donnees.banquemondiale.org/indicator/NY.GDP.PCAP.CD

# %%
df_pib_hab = pd.read_excel("Data_BM_PIB_hab.xls", header=3)

# %%
df_pib_hab.head(10)
# Out:
#           Country Name Country Code                    Indicator Name  \
# 0                Aruba          ABW  PIB par habitant ($ US courants)
# 1                  NaN          AFE  PIB par habitant ($ US courants)
# 2          Afghanistan          AFG  PIB par habitant ($ US courants)
# 3                  NaN          AFW  PIB par habitant ($ US courants)
# 4               Angola          AGO  PIB par habitant ($ US courants)
# 5              Albanie          ALB  PIB par habitant ($ US courants)
# 6              Andorre          AND  PIB par habitant ($ US courants)
# 7       Le monde arabe          ARB  PIB par habitant ($ US courants)
# 8  Émirats arabes unis          ARE  PIB par habitant ($ US courants)
# 9            Argentine          ARG  PIB par habitant ($ US courants)
#
#    Indicator Code        1960        1961         1962        1963  \
# 0  NY.GDP.PCAP.CD         NaN         NaN          NaN         NaN
# 1  NY.GDP.PCAP.CD  147.836769  147.238537   156.426780  182.521139
# 2  NY.GDP.PCAP.CD   59.773234   59.860900    58.458009   78.706429
# 3  NY.GDP.PCAP.CD  107.963779  113.114697   118.865837  123.478967
# 4  NY.GDP.PCAP.CD         NaN         NaN          NaN         NaN
# 5  NY.GDP.PCAP.CD         NaN         NaN          NaN         NaN
# 6  NY.GDP.PCAP.CD         NaN         NaN          NaN         NaN
# 7  NY.GDP.PCAP.CD         NaN         NaN          NaN         NaN
# 8  NY.GDP.PCAP.CD         NaN         NaN          NaN         NaN
# 9  NY.GDP.PCAP.CD         NaN         NaN  1155.890717  850.304579
#
#           1964         1965  ...          2011          2012          2013  \
# 0          NaN          NaN  ...  24985.013919  24712.493263  26441.619936
# 1   162.594548   180.489043  ...   1686.695763   1672.363658   1653.188436
# 2    82.095307   101.108325  ...    591.162798    641.871438    637.165464
# 3   131.892939   138.566819  ...   1827.518347   1936.390962   2123.392433
# 4          NaN          NaN  ...   4615.468219   5100.097027   5254.881126
# 5          NaN          NaN  ...   4437.142885   4247.629984   4413.060861
# 6          NaN          NaN  ...  43334.811413  38686.461264  39540.724814
# 7          NaN          NaN  ...   6695.858477   7265.966351   7314.827201
# 8          NaN          NaN  ...  39194.672240  40976.490746  42412.639500
# 9  1173.238105  1279.113778  ...  12848.864197  13082.664326  13080.254732
#
#            2014          2015          2016          2017          2018  \
# 0  26893.011506  28396.908423  28452.170615  29350.805019  30253.279358
# 1   1658.650062   1507.800256   1404.953164   1540.232473   1534.171767
# 2    613.856505    578.466353    509.220100    519.888913    493.756581
# 3   2166.743309   1886.248158   1666.422406   1606.978332   1695.959215
# 4   5408.411700   4166.979833   3506.073128   4095.810057   3289.643995
# 5   4578.631994   3952.801215   4124.055726   4531.020806   5284.380184
# 6  41303.929371  35770.776704  37475.635059  38964.904478  41791.969837
# 7   7247.972778   6185.083630   5938.791328   5941.064594   6402.380811
# 8  43751.805648  38663.400503  38141.867131  40644.791190  43839.324487
# 9  12334.798245  13789.060425  12790.242473  14613.041825  11633.498009
#
#            2019         2020
# 0           NaN          NaN
# 1   1485.307425  1330.140232
# 2    507.103392   508.808409
# 3   1772.339155  1714.426800
# 4   2809.626088  1895.770869
# 5   5355.847795  5215.276752
# 6  40897.330873          NaN
# 7   6403.540772  5654.950574
# 8  43103.336293          NaN
# 9   9912.281809  8441.919439
#
# [10 rows x 65 columns]

# %% [markdown]
# On ne garde les données que pour les années où il y a eu une édition des JO.

# %%
pib_hab = df_pib_hab[['Country Name','Country Code','1992','1996','2000','2004','2008','2012','2012','2016','2020']]

# %%
pib_hab.shape
# Out:
# (266, 11)

# %% [markdown]
# ## Population des pays
#
#
# Données téléchargées sur le lien suivant : https://donnees.banquemondiale.org/indicator/SP.POP.TOTL

# %%
df_pop = pd.read_excel("Data_BM_Pop.xls", header=3)

# %%
df_pop.head(10)
# Out:
#           Country Name Country Code     Indicator Name Indicator Code  \
# 0                Aruba          ABW  Population, total    SP.POP.TOTL
# 1                  NaN          AFE  Population, total    SP.POP.TOTL
# 2          Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3                  NaN          AFW  Population, total    SP.POP.TOTL
# 4               Angola          AGO  Population, total    SP.POP.TOTL
# 5              Albanie          ALB  Population, total    SP.POP.TOTL
# 6              Andorre          AND  Population, total    SP.POP.TOTL
# 7       Le monde arabe          ARB  Population, total    SP.POP.TOTL
# 8  Émirats arabes unis          ARE  Population, total    SP.POP.TOTL
# 9            Argentine          ARG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
# 5    1608800.0    1659800.0    1711319.0    1762621.0    1814135.0
# 6      13410.0      14378.0      15379.0      16407.0      17466.0
# 7   92197715.0   94724540.0   97334438.0  100034191.0  102832792.0
# 8      92417.0     100801.0     112112.0     125130.0     138049.0
# 9   20481781.0   20817270.0   21153042.0   21488916.0   21824427.0
#
#           1965  ...         2011         2012         2013         2014  \
# 0      57357.0  ...     102050.0     102565.0     103165.0     103776.0
# 1  148769974.0  ...  532760424.0  547482863.0  562601578.0  578075373.0
# 2    9956318.0  ...   30117411.0   31161378.0   32269592.0   33370804.0
# 3  107289875.0  ...  360285439.0  370243017.0  380437896.0  390882979.0
# 4    5770573.0  ...   24220660.0   25107925.0   26015786.0   26941773.0
# 5    1864791.0  ...    2905195.0    2900401.0    2895092.0    2889104.0
# 6      18542.0  ...      83748.0      82427.0      80770.0      79213.0
# 7  105736428.0  ...  363156846.0  371437642.0  379696477.0  387899835.0
# 8     149855.0  ...    8946778.0    9141598.0    9197908.0    9214182.0
# 9   22159644.0  ...   41261490.0   41733271.0   42202935.0   42669500.0
#
#           2015         2016         2017         2018         2019  \
# 0     104339.0     104865.0     105361.0     105846.0     106310.0
# 1  593871847.0  609978946.0  626392880.0  643090131.0  660046272.0
# 2   34413603.0   35383028.0   36296111.0   37171922.0   38041757.0
# 3  401586651.0  412551299.0  423769930.0  435229381.0  446911598.0
# 4   27884380.0   28842482.0   29816769.0   30809787.0   31825299.0
# 5    2880703.0    2876101.0    2873457.0    2866376.0    2854191.0
# 6      77993.0      77295.0      76997.0      77008.0      77146.0
# 7  396028301.0  404042892.0  411942825.0  419851989.0  427870273.0
# 8    9262896.0    9360975.0    9487206.0    9630966.0    9770526.0
# 9   43131966.0   43590368.0   44044811.0   44494502.0   44938712.0
#
#           2020
# 0     106766.0
# 1  677243299.0
# 2   38928341.0
# 3  458803476.0
# 4   32866268.0
# 5    2837743.0
# 6      77265.0
# 7  436080728.0
# 8    9890400.0
# 9   45376763.0
#
# [10 rows x 65 columns]

# %% [markdown]
# On ne garde les données que pour les années où il y a eu une édition des JO.

# %%
population = df_pop[['Country Name','Country Code','1992','1996','2000','2004','2008','2012','2012','2016','2020']]

# %%
population.shape
# Out:
# (266, 11)

# %% [markdown]
# ## Investissement dans le sport
#
#
# Il n’existe aucune base de données recensant directement l'investissement public dans le sport pour l’ensemble des pays. Mais l'OCDE a développé un système de classification des dépenses gouvernementales : COFOG (Classification of Functions of the Government). Pour approximer l'investissement public dans le sport, on retient la COFOG "recreation, culture and religion". On utilise les données du FMI et on complète pour avoir moins de valeurs manquantes avec celles d'Eurostat.
#
# Données FMI téléchargées sur le lien suivant : https://data.imf.org/?sk=5804c5e1-0502-4672-bdcd-671bcdc565a9
#
# Données Eurostat téléchargées sur le lien suivant : https://ec.europa.eu/eurostat/databrowser/view/GOV_10A_EXP__custom_1784023/default/table?lang=en

# %%
invest_sport_FMI = pd.read_excel("Invest_sport_recreation_culture_religion_FMI_domesticcurrency.xlsx", header=2)

# %%
invest_sport_FMI.head(10)
# Out:
#                      Unnamed: 0   1990 Unnamed: 2   1991 Unnamed: 4   1992  \
# 0  Afghanistan, Islamic Rep. of    NaN        NaN    NaN        NaN    NaN
# 1                       Albania    NaN        NaN    NaN        NaN    NaN
# 2              Armenia, Rep. of    NaN        NaN    NaN        NaN    NaN
# 3                     Australia    NaN        NaN    NaN        NaN    NaN
# 4                       Austria    NaN        NaN    NaN        NaN    NaN
# 5           Azerbaijan, Rep. of    NaN        NaN    NaN        NaN    NaN
# 6              Belarus, Rep. of    NaN        NaN    NaN        NaN    NaN
# 7                       Belgium    NaN        NaN    NaN        NaN    NaN
# 8                       Bolivia    NaN        NaN    NaN        NaN    NaN
# 9                      Bulgaria  0.604          M  1.308          M  1.769
#
#   Unnamed: 6   1993 Unnamed: 8   1994  ...         2016  Unnamed: 54  \
# 0        NaN    NaN        NaN    NaN  ...  3768.167024            M
# 1        NaN    NaN        NaN    NaN  ...  6355.930000            M
# 2        NaN    NaN        NaN    NaN  ...          NaN          NaN
# 3        NaN    NaN        NaN    NaN  ...    14.134000            B
# 4        NaN    NaN        NaN    NaN  ...  4303.930000            M
# 5        NaN    NaN        NaN    NaN  ...   697.620000            M
# 6        NaN    NaN        NaN    NaN  ...  1195.693000            M
# 7        NaN    NaN        NaN    NaN  ...  5397.300000            M
# 8        NaN    NaN        NaN    NaN  ...          NaN          NaN
# 9          M  2.405          M  3.929  ...   762.309000            M
#
#           2017  Unnamed: 56         2018  Unnamed: 58         2019  \
# 0  4100.661686            M          NaN          NaN          NaN
# 1  6440.030000            M  7381.560000            M  7309.950000
# 2    37.050782            B    36.401354            B    40.986571
# 3    14.306000            B    16.316000            B    16.546000
# 4  4390.120000            M  4473.780000            M  4600.280000
# 5   263.850000            M   312.800000            M   350.600000
# 6  1373.899722            M  1794.322002            M  1579.844377
# 7  5543.900000            M  5934.000000            M  5974.500000
# 8          NaN          NaN          NaN          NaN          NaN
# 9  1046.031000            M   850.551000            M   849.972000
#
#    Unnamed: 60         2020  Unnamed: 62
# 0          NaN          NaN          NaN
# 1            M  6842.130000            M
# 2            B    36.273902            B
# 3            B    17.332000            B
# 4            M  4531.300000            M
# 5            M          NaN          NaN
# 6            M  1598.126636            M
# 7            M          NaN          NaN
# 8          NaN          NaN          NaN
# 9            M          NaN          NaN
#
# [10 rows x 63 columns]

# %%
invest_sport_Eurostat = pd.read_excel("Invest_sport_recreation_culture_religion_Eurostat_domesticcurrency.xlsx", 
                                      sheet_name="Sheet 1", header=10)

# %%
invest_sport_Eurostat.head(10)
# Out:
#                                                TIME 1990  Unnamed: 2 1991  \
# 0                                      GEO (Labels)  NaN         NaN  NaN
# 1         European Union - 27 countries (from 2020)    :         NaN    :
# 2         European Union - 28 countries (2013-2020)    :         NaN    :
# 3             Euro area - 19 countries  (from 2015)    :         NaN    :
# 4                                           Belgium    :         NaN    :
# 5                                          Bulgaria    :         NaN    :
# 6                                           Czechia    :         NaN    :
# 7                                           Denmark    :         NaN    :
# 8  Germany (until 1990 former territory of the FRG)    :         NaN    :
# 9                                           Estonia    :         NaN    :
#
#    Unnamed: 4 1992  Unnamed: 6 1993  Unnamed: 8 1994  ...  Unnamed: 52  \
# 0         NaN  NaN         NaN  NaN         NaN  NaN  ...          NaN
# 1         NaN    :         NaN    :         NaN    :  ...          NaN
# 2         NaN    :         NaN    :         NaN    :  ...          NaN
# 3         NaN    :         NaN    :         NaN    :  ...          NaN
# 4         NaN    :         NaN    :         NaN    :  ...          NaN
# 5         NaN    :         NaN    :         NaN    :  ...          NaN
# 6         NaN    :         NaN    :         NaN    :  ...          NaN
# 7         NaN    :         NaN    :         NaN    :  ...          NaN
# 8         NaN    :         NaN    :         NaN    :  ...          NaN
# 9         NaN    :         NaN    :         NaN    :  ...          NaN
#
#        2016  Unnamed: 54      2017  Unnamed: 56      2018  Unnamed: 58  \
# 0       NaN          NaN       NaN          NaN       NaN          NaN
# 1  142177.8          NaN  148742.0          NaN  156795.6          NaN
# 2  157665.6          NaN  164094.4          NaN  171487.9          NaN
# 3  118042.8          NaN  122276.3          NaN  128674.3          NaN
# 4    5397.3          NaN    5543.9          NaN    5934.0          NaN
# 5     762.3          NaN    1046.0          NaN     850.6          NaN
# 6   61763.0          NaN   66816.0          NaN   79742.0          NaN
# 7   36458.0          NaN   37029.0          NaN   36592.0          NaN
# 8   31923.0          NaN   33598.0          NaN   35644.0          NaN
# 9     448.1          NaN     511.4          NaN     509.6          NaN
#
#        2019  Unnamed: 60     2020
# 0       NaN          NaN      NaN
# 1  161804.0          NaN        :
# 2  176424.5          NaN        :
# 3  132420.4          NaN        :
# 4    5974.5          NaN        :
# 5     850.0          NaN        :
# 6   82518.0          NaN        :
# 7   37158.0          NaN  39349.0
# 8   36004.0          NaN        :
# 9     563.8          NaN        :
#
# [10 rows x 62 columns]
